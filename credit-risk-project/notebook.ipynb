# %% [markdown]
# # Credit Risk: Run full pipeline
#
# Bu notebook sırasıyla: 1) Ön işlem 2) Eğitim 3) Değerlendirme adımlarını çalıştırır.

# %%
from IPython.display import Image, display

display(Image('results/confusion_matrix.png'))

# %%
# 3) Değerlendirme
# !python src/evaluate.py

# %%
# 2) Eğitim
# !python src/train.py

# %%
# 1) Ön işlem
# !python src/preprocess.py
# Out:
# Running cells with 'Python 3.13.2' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Pc/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Show classification report
print(open('results/classification_report.txt').read())
